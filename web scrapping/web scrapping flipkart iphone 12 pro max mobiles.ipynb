# %% [markdown]
# **Import the required Modules:**

# %%
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# **See the structure of URL:**

# %%
#https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page=1
#https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page=2

# %%
base_url ='https://www.flipkart.com/search?q=APPLE%2012%20PRO%20MAZ&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

# %% [markdown]
# **Create List for store the Data**

# %%
pd_name = []
price =[]
ratings = []
warranty = []
ratingsno = []
reviewsno = []
features = []
for i in range(1,3):
  time.sleep(3)
  req = requests.get(base_url+str(i))
  soup = BeautifulSoup(req.text,'html')

  #product name
  pdt_name = soup.findAll('div',attrs={'class':'_4rR01T'})
  [pd_name.append(i.text) for i in pdt_name]

  #price
  p = soup.findAll('div',attrs={'class':'_30jeq3 _1_WHN1'})
  [price.append(i.text) for i in p]

  #ratings
  r = soup.findAll('div',attrs={'class':'gUuXy-'})
  [ratings.append(i.span.div.text) for i in r]

  #warranty
  wl = soup.findAll('ul',attrs={'class':'_1xgFaf'})
  w = [i.findAll('li')[-1] for i in wl]
  [warranty.append(i.text) for i in w]

  #number of ratings and reviews
  a = soup.findAll('span',attrs={'class':'_2_R_DZ'})
  for i in a:
    a = i.text.split('&')
    ratingsno.append(a[0].split(" ")[0])
    reviewsno.append(a[1].split(" ")[0])

  #features
  prop = soup.findAll('ul',attrs={'class':'_1xgFaf'})
  for i in prop:
    a = i.findAll('li')[0:-2]
    b =[i.text for i in a]
    features.append(','.join(b))

# %%
print('pd_name= ',len(pd_name))
print('price = ',len(price))
print('ratings = ',len(ratings))
print('warranty = ',len(warranty))
print('ratingsno =',len(ratingsno))
print('reviewsno = ',len(reviewsno))
print('features = ',len(features))
# Out:
# pd_name=  24
# price =  24
# ratings =  24
# warranty =  24
# ratingsno = 24
# reviewsno =  24
# features =  24

# %%
data = pd.DataFrame({'Product':pd_name,
                     'Price':price,
                     'Ratings':ratings,
                     'Warranty':warranty,
                     'No of Ratings':ratingsno,
                     'No of Reviews':reviewsno,
                     'Features':features})
data
# Out:
#                                            Product      Price Ratings  \
# 0         APPLE iPhone 12 Pro Max (Silver, 128 GB)  ₹1,19,900     4.6
# 1           APPLE iPhone 12 Pro Max (Gold, 512 GB)  ₹1,49,900     4.6
# 2   APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)  ₹1,29,900     4.6
# 3   APPLE iPhone 12 Pro Max (Pacific Blue, 512 GB)  ₹1,49,900     4.6
# 4         APPLE iPhone 12 Pro Max (Silver, 512 GB)  ₹1,49,900     4.6
# 5   APPLE iPhone 12 Pro Max (Pacific Blue, 128 GB)  ₹1,19,900     4.6
# 6           APPLE iPhone 12 Pro Max (Gold, 256 GB)  ₹1,29,900     4.6
# 7    APPLE iPhone 13 Pro Max (Sierra Blue, 256 GB)  ₹1,39,900     4.7
# 8           APPLE iPhone 13 Pro Max (Gold, 256 GB)  ₹1,39,900     4.7
# 9           APPLE iPhone 13 Pro Max (Silver, 1 TB)  ₹1,79,900     4.7
# 10  APPLE iPhone 13 Pro Max (Alpine Green, 256 GB)  ₹1,39,900     4.7
# 11            APPLE iPhone 13 Pro Max (Gold, 1 TB)  ₹1,79,900     4.7
# 12        APPLE iPhone 13 Pro Max (Silver, 512 GB)  ₹1,59,900     4.7
# 13      APPLE iPhone 13 Pro Max (Graphite, 512 GB)  ₹1,59,900     4.7
# 14     APPLE iPhone 11 Pro Max (Space Grey, 64 GB)  ₹1,17,100     4.7
# 15        APPLE iPhone 13 Pro Max (Silver, 128 GB)  ₹1,29,900     4.7
# 16  APPLE iPhone 13 Pro Max (Alpine Green, 128 GB)  ₹1,29,900     4.7
# 17  APPLE iPhone 13 Pro Max (Alpine Green, 512 GB)  ₹1,59,900     4.7
# 18          APPLE iPhone 13 Pro Max (Gold, 128 GB)  ₹1,29,900     4.7
# 19      APPLE iPhone 13 Pro Max (Graphite, 128 GB)  ₹1,29,900     4.7
# 20         APPLE iPhone 11 Pro Max (Silver, 64 GB)  ₹1,17,100     4.7
# 21      APPLE iPhone 13 Pro Max (Graphite, 256 GB)  ₹1,39,900     4.7
# 22        APPLE iPhone 13 Pro Max (Silver, 256 GB)  ₹1,39,900     4.7
# 23        APPLE iPhone 13 Pro Max (Graphite, 1 TB)  ₹1,79,900     4.7
#
#                      Warranty No of Ratings No of Reviews  \
# 0   Brand Warranty for 1 Year         1,215            98
# 1   Brand Warranty for 1 Year         1,215            98
# 2   Brand Warranty for 1 Year         1,215            98
# 3   Brand Warranty for 1 Year         1,215            98
# 4   Brand Warranty for 1 Year         1,215            98
# 5   Brand Warranty for 1 Year         1,215            98
# 6   Brand Warranty for 1 Year         1,215            98
# 7   Brand Warranty for 1 Year           846            89
# 8   Brand Warranty for 1 Year           846            89
# 9   Brand Warranty for 1 Year           846            89
# 10  Brand Warranty for 1 Year           846            89
# 11  Brand Warranty for 1 Year           846            89
# 12  Brand Warranty for 1 Year           846            89
# 13  Brand Warranty for 1 Year           846            89
# 14  Brand Warranty for 1 Year         1,091           100
# 15  Brand Warranty for 1 Year           846            89
# 16  Brand Warranty for 1 Year           846            89
# 17  Brand Warranty for 1 Year           846            89
# 18  Brand Warranty for 1 Year           846            89
# 19  Brand Warranty for 1 Year           846            89
# 20  Brand Warranty for 1 Year         1,091           100
# 21  Brand Warranty for 1 Year           846            89
# 22  Brand Warranty for 1 Year           846            89
# 23  Brand Warranty for 1 Year           846            89
#
#                                              Features
# 0   128 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 1   512 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 2   256 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 3   512 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 4   512 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 5   128 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 6   256 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 7   256 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 8   256 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 9   1 TB ROM,17.02 cm (6.7 inch) Super Retina XDR ...
# 10  256 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 11  1 TB ROM,17.02 cm (6.7 inch) Super Retina XDR ...
# 12  512 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 13  512 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 14  64 GB ROM,16.51 cm (6.5 inch) Super Retina XDR...
# 15  128 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 16  128 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 17  512 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 18  128 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 19  128 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 20  64 GB ROM,16.51 cm (6.5 inch) Super Retina XDR...
# 21  256 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 22  256 GB ROM,17.02 cm (6.7 inch) Super Retina XD...
# 23  1 TB ROM,17.02 cm (6.7 inch) Super Retina XDR ...

# %%
data.to_csv('C:/SHAFRIN FARVEEN 2 ND BCA A/WEB SCRAPPING FLIPKART PYTHON iphone 13 pro max PROGRAM.csv')
